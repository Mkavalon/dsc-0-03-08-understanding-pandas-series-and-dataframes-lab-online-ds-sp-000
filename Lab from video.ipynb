# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('turnstile_180901.txt')
print(len(df))
df.head()
# Out:
# 197625
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# Practice
# Objectives
# You will be able to:
#
# Understand and explain what Pandas Series and DataFrames are and how they differ from dictionaries and lists
# Create Series & DataFrames from dictionaries and lists
# Manipulate columns in DataFrames (df.rename, df.drop)
# Manipulate the index in DataFrames (df.reindex, df.drop, df.rename)
# Manipulate column datatypes

# %% [markdown]
# Rename all the columns to lower case

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197625 entries, 0 to 197624
# Data columns (total 11 columns):
# C/A                                                                     197625 non-null object
# UNIT                                                                    197625 non-null object
# SCP                                                                     197625 non-null object
# STATION                                                                 197625 non-null object
# LINENAME                                                                197625 non-null object
# DIVISION                                                                197625 non-null object
# DATE                                                                    197625 non-null object
# TIME                                                                    197625 non-null object
# DESC                                                                    197625 non-null object
# ...

# %%
df.columns
#too much white space
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES',
#        'EXITS                                                               '],
#       dtype='object')

# %%
new_columns = []
for column in df.columns:
    new_columns.append(column.lower())

# %%
df.columns = new_columns

# %%
df.head()
# Out:
#     c/a  unit       scp station linename division        date      time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %%
# another way to lowercase is list comprehension
df.columns = [column.lower for column in df.columns]
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-3d7e76bcfb21> in <module>()
#       1 # another way to lowercase is list comprehension
# ----> 2 df.columns = [column.lower for column in df.columns]
#       3 df.head()
#
# <ipython-input-22-3d7e76bcfb21> in <listcomp>(.0)
#       1 # another way to lowercase is list comprehension
# ----> 2 df.columns = [column.lower for column in df.columns]
#       3 df.head()
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'lower'

# %% [markdown]
# change index to Line Names

# %%
#Your code here
# also do df.set_index('LINENAME', inplace = True) to make permanent change
df = df.set_index('linename')
df.head()
# Out:
#            c/a  unit       scp station division        date      time  \
# linename
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00
#
#              desc  entries  \
# linename
# NQR456W   REGULAR  6736067
# NQR456W   REGULAR  6736087
# NQR456W   REGULAR  6736105
# NQR456W   REGULAR  6736180
# NQR456W   REGULAR  6736349
#
#           exits
# linename
# NQR456W                                             2283184
# NQR456W                                             2283188
# NQR456W                                             2283229
# NQR456W                                             2283314
# NQR456W                                             2283384

# %%
df.index.unique()
# Out:
# Index(['NQR456W', 'NQRW', 'ACENQRS1237W', 'BDFMNQRW', 'NRW', 'LNQR456W',
#        'JNQRZ6W', 'RNW', 'R1W', 'FJMZ',
#        ...
#        '7', '7NQW', 'NQW', '7EFMR', '2345R', '2345', '2345BDNQR', '2345S',
#        '34', '5'],
#       dtype='object', name='linename', length=113)

# %%
df.loc['7EFMR']
# Out:
#            c/a  unit       scp         station division        date      time  \
# linename
# 7EFMR     R525  R018  02-00-00  74 ST-BROADWAY      IRT  08/25/2018  00:00:00
# 7EFMR     R525  R018  02-00-00  74 ST-BROADWAY      IRT  08/25/2018  04:00:00
# 7EFMR     R525  R018  02-00-00  74 ST-BROADWAY      IRT  08/25/2018  08:00:00
# 7EFMR     R525  R018  02-00-00  74 ST-BROADWAY      IRT  08/25/2018  12:00:00
# 7EFMR     R525  R018  02-00-00  74 ST-BROADWAY      IRT  08/25/2018  16:00:00
# 7EFMR     R525  R018  02-00-00  74 ST-BROADWAY      IRT  08/25/2018  20:00:00
# 7EFMR     R525  R018  02-00-00  74 ST-BROADWAY      IRT  08/26/2018  00:00:00
# 7EFMR     R525  R018  02-00-00  74 ST-BROADWAY      IRT  08/26/2018  04:00:00
# 7EFMR     R525  R018  02-00-00  74 ST-BROADWAY      IRT  08/26/2018  08:00:00
# 7EFMR     R525  R018  02-00-00  74 ST-BROADWAY      IRT  08/26/2018  12:00:00
# 7EFMR     R525  R018  02-00-00  74 ST-BROADWAY      IRT  08/26/2018  16:00:00
# ...

# %%
# another way to get data with a particular index---i cant get this to run
df[df['linename'] == '7EFMR']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'linename'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-66-488794a4913f> in <module>()
# ...

# %% [markdown]
# Painstakingly change the index back

# %%
# Your code here
#or df.reset_index(inplace = True)
df = df.reset_index() #Not that painful
df.head()
# Out:
#   linename   c/a  unit       scp station division        date      time  \
# 0  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# 1  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
# 2  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00
# 3  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00
# 4  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# Create another column 'Num_Lines' that is a count of how many lines pass through a station. Then sort your dataframe by this column in descending order.

# %%
df[df['station'] == '103 ST']['linename'].unique()
# Out:
# array(['BC', '1', '6'], dtype=object)

# %%
unique_linenames = df.groupby('station')['linename'].nunique()
# Out:
# station
# 1 AV               1
# 103 ST             3
# 103 ST-CORONA      1
# 104 ST             2
# 110 ST             1
# 111 ST             3
# 116 ST             3
# 116 ST-COLUMBIA    1
# 121 ST             1
# 125 ST             4
# 135 ST             2
# 137 ST CITY COL    1
# 138/GRAND CONC     1
# 14 ST              3
# 14 ST-UNION SQ     2
# 145 ST             2
# 149/GRAND CONC     1
# 14TH STREET        1
# 15 ST-PROSPECT     1
# 155 ST             2
# 157 ST             1
# 161/YANKEE STAD    2
# 167 ST             2
# 168 ST             2
# 169 ST             1
# 170 ST             2
# 174 ST             1
# 175 ST             1
# 176 ST             1
# 18 AV              3
#                   ..
# SUTPHIN-ARCHER     1
# SUTTER AV          1
# SUTTER AV-RUTLD    1
# THIRTY ST          1
# THIRTY THIRD ST    1
# TIMES SQ-42 ST     3
# TOMPKINSVILLE      1
# TREMONT AV         1
# TWENTY THIRD ST    1
# UNION ST           1
# UTICA AV           1
# V.CORTLANDT PK     1
# ...

# %%
unique_linenames
# Out:
# station
# 1 AV               1
# 103 ST             3
# 103 ST-CORONA      1
# 104 ST             2
# 110 ST             1
# 111 ST             3
# 116 ST             3
# 116 ST-COLUMBIA    1
# 121 ST             1
# 125 ST             4
# 135 ST             2
# 137 ST CITY COL    1
# 138/GRAND CONC     1
# 14 ST              3
# 14 ST-UNION SQ     2
# 145 ST             2
# 149/GRAND CONC     1
# 14TH STREET        1
# 15 ST-PROSPECT     1
# 155 ST             2
# 157 ST             1
# 161/YANKEE STAD    2
# 167 ST             2
# 168 ST             2
# 169 ST             1
# 170 ST             2
# 174 ST             1
# 175 ST             1
# 176 ST             1
# 18 AV              3
#                   ..
# SUTPHIN-ARCHER     1
# SUTTER AV          1
# SUTTER AV-RUTLD    1
# THIRTY ST          1
# THIRTY THIRD ST    1
# TIMES SQ-42 ST     3
# TOMPKINSVILLE      1
# TREMONT AV         1
# TWENTY THIRD ST    1
# UNION ST           1
# UTICA AV           1
# V.CORTLANDT PK     1
# ...

# %%
df.head()
# Out:
#   linename   c/a  unit       scp station division        date      time  \
# 0  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# 1  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
# 2  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00
# 3  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00
# 4  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %%
#from video
df.set_index('station', inplace = True)

# %%
df.head()
# Out:
#         linename   c/a  unit       scp division        date      time  \
# station
# 59 ST    NQR456W  A002  R051  02-00-00      BMT  08/25/2018  00:00:00
# 59 ST    NQR456W  A002  R051  02-00-00      BMT  08/25/2018  04:00:00
# 59 ST    NQR456W  A002  R051  02-00-00      BMT  08/25/2018  08:00:00
# 59 ST    NQR456W  A002  R051  02-00-00      BMT  08/25/2018  12:00:00
# 59 ST    NQR456W  A002  R051  02-00-00      BMT  08/25/2018  16:00:00
#
#             desc  entries  \
# station
# 59 ST    REGULAR  6736067
# 59 ST    REGULAR  6736087
# 59 ST    REGULAR  6736105
# 59 ST    REGULAR  6736180
# 59 ST    REGULAR  6736349
#
#          exits
# station
# 59 ST                                              2283184
# 59 ST                                              2283188
# 59 ST                                              2283229
# 59 ST                                              2283314
# 59 ST                                              2283384

# %%
#from video
df[df['station'] == '103 ST']['linename'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'station'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-74-d37192c0d180> in <module>()
#       1 #from video
# ...

# %%
df['Num_Lines'] = unique_linenames

# %%
df.head()
# Out:
#         linename   c/a  unit       scp division        date      time  \
# station
# 59 ST    NQR456W  A002  R051  02-00-00      BMT  08/25/2018  00:00:00
# 59 ST    NQR456W  A002  R051  02-00-00      BMT  08/25/2018  04:00:00
# 59 ST    NQR456W  A002  R051  02-00-00      BMT  08/25/2018  08:00:00
# 59 ST    NQR456W  A002  R051  02-00-00      BMT  08/25/2018  12:00:00
# 59 ST    NQR456W  A002  R051  02-00-00      BMT  08/25/2018  16:00:00
#
#             desc  entries  \
# station
# 59 ST    REGULAR  6736067
# 59 ST    REGULAR  6736087
# 59 ST    REGULAR  6736105
# 59 ST    REGULAR  6736180
# 59 ST    REGULAR  6736349
#
#          exits                                                                 \
# station
# 59 ST                                              2283184
# 59 ST                                              2283188
# 59 ST                                              2283229
# 59 ST                                              2283314
# ...

# %%
unique_linenames['59 ST']
# Out:
# 3

# %% [markdown]
# WRITE a function to clean a column name
